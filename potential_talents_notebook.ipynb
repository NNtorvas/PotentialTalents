# %% [markdown]
# # Potential Talents Project

# %% [markdown]
# ## Background:
#
# As a talent sourcing and management company, we are interested in finding talented individuals for sourcing these candidates to technology companies. Finding talented candidates is not easy, for several reasons. The first reason is one needs to understand what the role is very well to fill in that spot, this requires understanding the client’s needs and what they are looking for in a potential candidate. The second reason is one needs to understand what makes a candidate shine for the role we are in search for. Third, where to find talented individuals is another challenge.
#
# The nature of our job requires a lot of human labor and is full of manual operations. Towards automating this process we want to build a better approach that could save us time and finally help us spot potential candidates that could fit the roles we are in search for. Moreover, going beyond that for a specific role we want to fill in we are interested in developing a machine learning powered pipeline that could spot talented individuals, and rank them based on their fitness.
#
# We are right now semi-automatically sourcing a few candidates, therefore the sourcing part is not a concern at this time but we expect to first determine best matching candidates based on how fit these candidates are for a given role. We generally make these searches based on some keywords such as “full-stack software engineer”, “engineering manager” or “aspiring human resources” based on the role we are trying to fill in. These keywords might change, and you can expect that specific keywords will be provided to you.
#
# Assuming that we were able to list and rank fitting candidates, we then employ a review procedure, as each candidate needs to be reviewed and then determined how good a fit they are through manual inspection. This procedure is done manually and at the end of this manual review, we might choose not the first fitting candidate in the list but maybe the 7th candidate in the list. If that happens, we are interested in being able to re-rank the previous list based on this information. This supervisory signal is going to be supplied by starring the 7th candidate in the list. Starring one candidate actually sets this candidate as an ideal candidate for the given role. Then, we expect the list to be re-ranked each time a candidate is starred.
#
# ## Data Description:
#
# The data comes from our sourcing efforts. We removed any field that could directly reveal personal details and gave a unique identifier for each candidate.
#
# ### Attributes:
# * id : unique identifier for candidate (numeric)
#
# * job_title : job title for candidate (text)
#
# * location : geographical location for candidate (text)
#
# * connections: number of connections candidate has, 500+ means over 500 (text)
#
# ### Output (desired target):
# * fit - how fit the candidate is for the role? (numeric, probability between 0-1)
#
# Keywords: “Aspiring human resources” or “seeking human resources”

# %% [markdown]
# ### Import Libraries

# %%
# random
import random

# cell output clear tool
from IPython.display import clear_output

# data
import pandas as pd
import numpy as np

# visualisations
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

from gensim.models import Word2Vec

from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nntor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nntor\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\nntor\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nntor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Load Data and Data Preprocessing

# %%
data = pd.read_csv('Data/potential-talents - Aspiring human resources - seeking human resources.csv')
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %%
# get info about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    int64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
#  4   fit         0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.2+ KB

# %%
# we will drop fit column because is full of NaNs
data.drop('fit', axis=1, inplace=True)

# %%
# we will check for duplicates by removing the id col, which is unique for each row
duplicates_set = data.copy()
duplicates_set.drop('id', axis=1, inplace=True)
print(f'Number of duplicates: {duplicates_set.duplicated().sum()}')
# Out:
# Number of duplicates: 51

# %%
# we will drop the duplicate values
data = data.set_index('id')
data.drop_duplicates(inplace=True)
print(f'Number of duplicates: {data.duplicated().sum()}')
data.info()
# Out:
# Number of duplicates: 0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 1 to 104
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   job_title   53 non-null     object
#  1   location    53 non-null     object
#  2   connection  53 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# ### We will se the values of job titles in order to modify them for further

# %%
data['job_title'].value_counts()
# Out:
# Aspiring Human Resources Professional                                                                                    2
# 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional                 1
# Lead Official at Western Illinois University                                                                             1
# Senior Human Resources Business Partner at Heil Environmental                                                            1
# Aspiring Human Resources Professional | An energetic and Team-Focused Leader                                             1
# HR Manager at Endemol Shine North America                                                                                1
# Human Resources professional for the world leader in GIS software                                                        1
# RRP Brand Portfolio Executive at JTI (Japan Tobacco International)                                                       1
# Information Systems Specialist and Programmer with a love for data and organization.                                     1
# Bachelor of Science in Biology from Victoria University of Wellington                                                    1
# Human Resources Management Major                                                                                         1
# Director Human Resources  at EY                                                                                          1
# Undergraduate Research Assistant at Styczynski Lab                                                                       1
# Seeking employment opportunities within Customer Service or Patient Care                                                 1
# Liberal Arts Major. Aspiring Human Resources Analyst.                                                                    1
# Admissions Representative at Community medical center long beach                                                         1
# Seeking Human  Resources Opportunities. Open to travel and relocation.                                                   1
# Student at Westfield State University                                                                                    1
# Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint               1
# Student                                                                                                                  1
# Seeking Human Resources Position                                                                                         1
# Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis    1
# Human Resources Generalist at Loparex                                                                                    1
# Business Intelligence and Analytics at Travelers                                                                         1
# Always set them up for Success                                                                                           1
# Junior MES Engineer| Information Systems                                                                                 1
# Human Resources Generalist at Schwan's                                                                                   1
# Native English Teacher at EPIK (English Program in Korea)                                                                1
# Seeking Human Resources Opportunities                                                                                    1
# People Development Coordinator at Ryan                                                                                   1
# Advisory Board Member at Celal Bayar University                                                                          1
# Aspiring Human Resources Specialist                                                                                      1
# Student at Humber College and Aspiring Human Resources Generalist                                                        1
# HR Senior Specialist                                                                                                     1
# Seeking Human Resources HRIS and Generalist Positions                                                                    1
# Student at Chapman University                                                                                            1
# SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR              1
# Human Resources Coordinator at InterContinental Buckhead Atlanta                                                         1
# Aspiring Human Resources Management student seeking an internship                                                        1
# Experienced Retail Manager and aspiring Human Resources Professional                                                     1
# Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation                  1
# Human Resources, Staffing and Recruiting Professional                                                                    1
# Human Resources Specialist at Luxottica                                                                                  1
# Director of Human Resources North America, Groupe Beneteau                                                               1
# Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.                           1
# Human Resources Generalist at ScottMadden, Inc.                                                                          1
# Business Management Major and Aspiring Human Resources Manager                                                           1
# Aspiring Human Resources Manager, seeking internship in Human Resources.                                                 1
# Human Resources Professional                                                                                             1
# Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621                     1
# Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment    1
# Director Of Administration at Excellence Logging                                                                         1
# Name: job_title, dtype: int64

# %% [markdown]
# We should remove numbers, special characters, whitespace, both capital and small letters, acronyms, and stopwords from the values of job title.

# %%
# create a function to deal with all the things we want to change in the job title column
def clean_text(text):

  # tokenize
  tokenizer = RegexpTokenizer(r'\w+')
  tokens = tokenizer.tokenize(text)

  # lemmatize + lowercase
  lemmatizer = WordNetLemmatizer()
  tokens = [lemmatizer.lemmatize(token.lower(), pos='v') for token in tokens]
  
  # remove stopwords
  keep_words = [token for token in tokens if token not in stopwords.words('english')]
  row_text = ' '.join(keep_words)
  row_text = ' '.join([word for word in row_text.split() if len(word)>1])  # remove one letter words
  row_text = re.sub(r'\w*\d\w*', '', row_text).strip()
  return row_text

# apply our function
data['job_title'] = data['job_title'].apply(clean_text)

# %%
# we will replace tha acronyms manually also
data.replace({'job_title' : {'magna cum laude' : 'with great distinction', 'chro' : 'chief human resources officer', 'svp' : 'senior vice president'
        ,'gphr' : 'global professional in human resources', 'hris' : 'human resources information system'
        , 'csr' : 'corporate social responsibility', 'sphr' : 'strategic and policy-making certification'
        , 'hr' : 'human resources', 'rrp' : 'recommended retail prices'}}, regex=True, inplace=True)

data['job_title'] = data['job_title'].apply(clean_text)
data.head()
# Out:
#                                             job_title  \
# id
# 1   bauer college business graduate great distinct...
# 2   native english teacher epik english program korea
# 3                 aspire human resources professional
# 4                 people development coordinator ryan
# 5        advisory board member celal bayar university
#
#                                location connection
# id
# 1                        Houston, Texas         85
# 2                                Kanada      500+
# 3   Raleigh-Durham, North Carolina Area         44
# 4                         Denton, Texas      500+
# 5                        İzmir, Türkiye      500+

# %%
data['job_title'].value_counts()
# Out:
# aspire human resources professional                                                                                                                                                                                         2
# bauer college business graduate great distinction aspire human resources professional                                                                                                                                       1
# lead official western illinois university                                                                                                                                                                                   1
# senior human resources business partner heil environmental                                                                                                                                                                  1
# aspire human resources professional energetic team focus leader                                                                                                                                                             1
# human resources manager endemol shine north america                                                                                                                                                                         1
# human resources professional world leader gi software                                                                                                                                                                       1
# recommend retail price brand portfolio executive jti japan tobacco international                                                                                                                                            1
# information systems specialist programmer love data organization                                                                                                                                                            1
# bachelor science biology victoria university wellington                                                                                                                                                                     1
# human resources management major                                                                                                                                                                                            1
# director human resources ey                                                                                                                                                                                                 1
# undergraduate research assistant styczynski lab                                                                                                                                                                             1
# seek employment opportunities within customer service patient care                                                                                                                                                          1
# liberal arts major aspire human resources analyst                                                                                                                                                                           1
# admissions representative community medical center long beach                                                                                                                                                               1
# seek human resources opportunities open travel relocation                                                                                                                                                                   1
# student westfield state university                                                                                                                                                                                          1
# student indiana university kokomo business management retail manager delphi hardware paint                                                                                                                                  1
# student                                                                                                                                                                                                                     1
# seek human resources position                                                                                                                                                                                               1
# aspire human resources manager graduate may seek entry level human resources position st louis                                                                                                                              1
# human resources generalist loparex                                                                                                                                                                                          1
# business intelligence analytics travelers                                                                                                                                                                                   1
# always set success                                                                                                                                                                                                          1
# junior mes engineer information systems                                                                                                                                                                                     1
# human resources generalist schwan                                                                                                                                                                                           1
# native english teacher epik english program korea                                                                                                                                                                           1
# seek human resources opportunities                                                                                                                                                                                          1
# people development coordinator ryan                                                                                                                                                                                         1
# advisory board member celal bayar university                                                                                                                                                                                1
# aspire human resources specialist                                                                                                                                                                                           1
# student humber college aspire human resources generalist                                                                                                                                                                    1
# human resources senior specialist                                                                                                                                                                                           1
# seek human resources human resources information system generalist position                                                                                                                                                 1
# student chapman university                                                                                                                                                                                                  1
# senior vice president chief human resources officer market communications corporate social responsibility officer engie houston woodlands energy global professional human resources strategic policy make certification    1
# human resources coordinator intercontinental buckhead atlanta                                                                                                                                                               1
# aspire human resources management student seek internship                                                                                                                                                                   1
# experience retail manager aspire human resources professional                                                                                                                                                               1
# human resources conflict management policies procedures talent management benefit compensation                                                                                                                              1
# human resources staff recruit professional                                                                                                                                                                                  1
# human resources specialist luxottica                                                                                                                                                                                        1
# director human resources north america groupe beneteau                                                                                                                                                                      1
# retire army national guard recruiter office manager seek position human resources                                                                                                                                           1
# human resources generalist scottmadden inc                                                                                                                                                                                  1
# business management major aspire human resources manager                                                                                                                                                                    1
# aspire human resources manager seek internship human resources                                                                                                                                                              1
# human resources professional                                                                                                                                                                                                1
# nortia staff seek human resources payroll administrative professionals                                                                                                                                                      1
# aspire human resources professional passionate help create inclusive engage work environment                                                                                                                                1
# director administration excellence log                                                                                                                                                                                      1
# Name: job_title, dtype: int64

# %% [markdown]
# ### We will se the values of location in order to modify them for further

# %%
data['location'].value_counts()
# Out:
# Houston, Texas Area                    4
# Raleigh-Durham, North Carolina Area    3
# Greater New York City Area             3
# Austin, Texas Area                     2
# Amerika Birleşik Devletleri            2
# Kanada                                 2
# Greater Philadelphia Area              2
# Greater Atlanta Area                   2
# Torrance, California                   1
# Highland, California                   1
# Gaithersburg, Maryland                 1
# Baltimore, Maryland                    1
# Milpitas, California                   1
# Greater Chicago Area                   1
# Houston, Texas                         1
# Long Beach, California                 1
# Chattanooga, Tennessee Area            1
# Bridgewater, Massachusetts             1
# Lafayette, Indiana                     1
# Kokomo, Indiana Area                   1
# Las Vegas, Nevada Area                 1
# Cape Girardeau, Missouri               1
# Greater Los Angeles Area               1
# Los Angeles, California                1
# Dallas/Fort Worth Area                 1
# Myrtle Beach, South Carolina Area      1
# Baton Rouge, Louisiana Area            1
# New York, New York                     1
# San Jose, California                   1
# Greater Boston Area                    1
# Monroe, Louisiana Area                 1
# Virginia Beach, Virginia               1
# Greater Grand Rapids, Michigan Area    1
# Jackson, Mississippi Area              1
# Chicago, Illinois                      1
# Atlanta, Georgia                       1
# Lake Forest, California                1
# San Francisco Bay Area                 1
# İzmir, Türkiye                         1
# Denton, Texas                          1
# Katy, Texas                            1
# Name: location, dtype: int64

# %%
# replace manually also some problem values in location
data.replace({'location' : {'Amerika Birleşik Devletleri' : 'United States of America', 'Houston, Texas Area' : 'Houston, Texas', 'Austin, Texas Area' : 'Austin, Texas',
                            'Kanada' : 'Canada', 'Kokomo, Indiana Area' : 'Kokomo, Indiana', 'Türkiye' : 'Turkey'}}, regex=True, inplace=True)
data['location'] = data['location'].apply(clean_text)
data.head()
# Out:
#                                             job_title  \
# id
# 1   bauer college business graduate great distinct...
# 2   native english teacher epik english program korea
# 3                 aspire human resources professional
# 4                 people development coordinator ryan
# 5        advisory board member celal bayar university
#
#                               location connection
# id
# 1                        houston texas         85
# 2                               canada      500+
# 3   raleigh durham north carolina area         44
# 4                         denton texas      500+
# 5                        i̇zmir turkey      500+

# %%
data['location'].value_counts()
# Out:
# houston texas                         5
# raleigh durham north carolina area    3
# greater new york city area            3
# greater philadelphia area             2
# greater atlanta area                  2
# canada                                2
# austin texas                          2
# unite state america                   2
# lake forest california                1
# atlanta georgia                       1
# greater los angeles area              1
# cape girardeau missouri               1
# las vegas nevada area                 1
# kokomo indiana                        1
# lafayette indiana                     1
# bridgewater massachusetts             1
# long beach california                 1
# torrance california                   1
# greater chicago area                  1
# denton texas                          1
# milpitas california                   1
# baltimore maryland                    1
# gaithersburg maryland                 1
# highland california                   1
# los angeles california                1
# chattanooga tennessee area            1
# myrtle beach south carolina area      1
# baton rouge louisiana area            1
# i̇zmir turkey                         1
# dallas fort worth area                1
# new york new york                     1
# san jose california                   1
# greater boston area                   1
# monroe louisiana area                 1
# virginia beach virginia               1
# greater grand rapids michigan area    1
# jackson mississippi area              1
# san francisco bay area                1
# chicago illinois                      1
# katy texas                            1
# Name: location, dtype: int64

# %% [markdown]
# ### Combine job title field together with location in order to you both as keywords of each employee

# %%
data['keywords'] = (data['job_title'] + ' ' + data['location'])
data.head()
# Out:
#                                             job_title  \
# id
# 1   bauer college business graduate great distinct...
# 2   native english teacher epik english program korea
# 3                 aspire human resources professional
# 4                 people development coordinator ryan
# 5        advisory board member celal bayar university
#
#                               location connection  \
# id
# 1                        houston texas         85
# 2                               canada      500+
# 3   raleigh durham north carolina area         44
# 4                         denton texas      500+
# 5                        i̇zmir turkey      500+
#
#                                              keywords
# id
# 1   bauer college business graduate great distinct...
# 2   native english teacher epik english program ko...
# 3   aspire human resources professional raleigh du...
# 4    people development coordinator ryan denton texas
# 5   advisory board member celal bayar university i...

# %% [markdown]
# ### Word2Vec Model to make the ranking based on keywords

# %%
def word2vector(feature, keyword, df, min_count=1, window=5, epochs=10):

  # put df's rows in a list. This is our corpus.
  corpus = df[feature].tolist()

  # ADD ALSO OUR KEYWORDS IN CORPUS to be trained data for our model and have their own vectors
  temp_keywords = ' '.join(keyword)
  corpus.append(temp_keywords) 
    
  # break our rows into tokens
  tokens = [word_tokenize(row) for row in corpus]

  # train our Word2Vec model
  # sg = 0 -> skip-gram | sg = 1 -> CBOW
  model = Word2Vec(tokens, min_count=min_count, window=window,sg=0,batch_words=10)
  model.train(tokens, total_examples=1, epochs=epochs)

  # compute our keywords vector by adding each keywords's vector
  p = np.array(0.)
  for k in keyword:
    p = p + model.wv[k]
    
  # init
  cs = []
  
  # we created vectors for our keywords through our model but we dont need the keywords in our tokens for analysis, so we remove the keywords from the tokens
  tokens.pop()
    
  # for each word in each token, if a keyword is in our token we add their vectors in order to
  # compute the cosine similarity with our keyword's vector previously computed
  for i in tokens:
    a = np.array(0.)
    for j in i:
      if j in keyword:
        a = a + model.wv[j]
    cs.append(cosine_similarity(np.mean(np.array(p)).reshape(-1, 1), np.mean(a).reshape(-1, 1)).item())
    
  # add the cosine similarities into our df and sort the values based on cs
  df['cosine_similarity'] = np.array(cs)
  df = df.sort_values('cosine_similarity', ascending=False)
  return df

# %%
feature = 'keywords'
keywords = ['seeking', 'human', 'resources']

d_w2v = data.copy()
d_w2v = word2vector(feature, keywords, d_w2v)
d_w2v
# Out:
#                                              job_title  \
# id
# 1    bauer college business graduate great distinct...
# 83   human resources manager endemol shine north am...
# 74                        human resources professional
# 75   nortia staff seek human resources payroll admi...
# 76   aspire human resources professional passionate...
# 77   human resources conflict management policies p...
# 79   liberal arts major aspire human resources analyst
# 81   senior human resources business partner heil e...
# 82   aspire human resources professional energetic ...
# 84   human resources professional world leader gi s...
# 72   business management major aspire human resourc...
# 88                    human resources management major
# 89                         director human resources ey
# 94   seek human resources opportunities open travel...
# 97                 aspire human resources professional
# 99                       seek human resources position
# 100  aspire human resources manager graduate may se...
# 101                 human resources generalist loparex
# 73   aspire human resources manager seek internship...
# 78                   human resources generalist schwan
# 71          human resources generalist scottmadden inc
# 27   aspire human resources management student seek...
# 3                  aspire human resources professional
# 6                    aspire human resources specialist
# 7    student humber college aspire human resources ...
# 8                    human resources senior specialist
# 70   retire army national guard recruiter office ma...
# 12   senior vice president chief human resources of...
# 13   human resources coordinator intercontinental b...
# 10   seek human resources human resources informati...
# 69   director human resources north america groupe ...
# 66   experience retail manager aspire human resourc...
# 68                human resources specialist luxottica
# 28                  seek human resources opportunities
# 67          human resources staff recruit professional
# 80             junior mes engineer information systems
# 95                  student westfield state university
# 103                                 always set success
# 102          business intelligence analytics travelers
# 4                  people development coordinator ryan
# 5         advisory board member celal bayar university
# 98                                             student
# 96   student indiana university kokomo business man...
# 93   admissions representative community medical ce...
# 92   seek employment opportunities within customer ...
# 91           lead official western illinois university
# 90     undergraduate research assistant styczynski lab
# 2    native english teacher epik english program korea
# 87   bachelor science biology victoria university w...
# 86   information systems specialist programmer love...
# 85   recommend retail price brand portfolio executi...
# 11                          student chapman university
# 104             director administration excellence log
#
#                                location connection  \
# id
# 1                         houston texas         85
# 83               los angeles california        268
# 74                  greater boston area         16
# 75                  san jose california      500+
# 76                    new york new york        212
# 77               dallas fort worth area        409
# 79           baton rouge louisiana area          7
# 81           chattanooga tennessee area        455
# 82                         austin texas        174
# 84                  highland california         50
# 72                monroe louisiana area          5
# 88                  milpitas california         18
# 89                 greater atlanta area        349
# 94                  unite state america        415
# 97                       kokomo indiana         71
# 99                las vegas nevada area         48
# 100             cape girardeau missouri        103
# 101  raleigh durham north carolina area      500+
# 73                        houston texas          7
# 78                  unite state america      500+
# 71   raleigh durham north carolina area      500+
# 27                        houston texas      500+
# 3    raleigh durham north carolina area         44
# 6            greater new york city area          1
# 7                                canada         61
# 8                san francisco bay area      500+
# 70              virginia beach virginia         82
# 12                        houston texas      500+
# 13                      atlanta georgia      500+
# 10            greater philadelphia area      500+
# 69   greater grand rapids michigan area      500+
# 66                         austin texas         57
# 68           greater new york city area      500+
# 28                     chicago illinois        390
# 67             jackson mississippi area      500+
# 80     myrtle beach south carolina area         52
# 95            bridgewater massachusetts         57
# 103            greater los angeles area      500+
# 102          greater new york city area         49
# 4                          denton texas      500+
# 5                         i̇zmir turkey      500+
# 98                        houston texas          4
# 96                    lafayette indiana         19
# 93                long beach california          9
# 92                  torrance california         64
# 91                 greater chicago area         39
# 90                 greater atlanta area        155
# 2                                canada      500+
# 87                   baltimore maryland         40
# 86                gaithersburg maryland          4
# 85            greater philadelphia area      500+
# 11               lake forest california          2
# 104                          katy texas      500+
#
#                                               keywords  cosine_similarity
# id
# 1    bauer college business graduate great distinct...                1.0
# 83   human resources manager endemol shine north am...                1.0
# 74    human resources professional greater boston area                1.0
# 75   nortia staff seek human resources payroll admi...                1.0
# 76   aspire human resources professional passionate...                1.0
# 77   human resources conflict management policies p...                1.0
# 79   liberal arts major aspire human resources anal...                1.0
# 81   senior human resources business partner heil e...                1.0
# 82   aspire human resources professional energetic ...                1.0
# 84   human resources professional world leader gi s...                1.0
# 72   business management major aspire human resourc...                1.0
# 88   human resources management major milpitas cali...                1.0
# 89    director human resources ey greater atlanta area                1.0
# 94   seek human resources opportunities open travel...                1.0
# 97   aspire human resources professional kokomo ind...                1.0
# 99   seek human resources position las vegas nevada...                1.0
# 100  aspire human resources manager graduate may se...                1.0
# 101  human resources generalist loparex raleigh dur...                1.0
# 73   aspire human resources manager seek internship...                1.0
# 78   human resources generalist schwan unite state ...                1.0
# 71   human resources generalist scottmadden inc ral...                1.0
# 27   aspire human resources management student seek...                1.0
# 3    aspire human resources professional raleigh du...                1.0
# 6    aspire human resources specialist greater new ...                1.0
# 7    student humber college aspire human resources ...                1.0
# 8    human resources senior specialist san francisc...                1.0
# 70   retire army national guard recruiter office ma...                1.0
# 12   senior vice president chief human resources of...                1.0
# 13   human resources coordinator intercontinental b...                1.0
# 10   seek human resources human resources informati...                1.0
# 69   director human resources north america groupe ...                1.0
# 66   experience retail manager aspire human resourc...                1.0
# 68   human resources specialist luxottica greater n...                1.0
# 28   seek human resources opportunities chicago ill...                1.0
# 67   human resources staff recruit professional jac...                1.0
# 80   junior mes engineer information systems myrtle...                0.0
# 95   student westfield state university bridgewater...                0.0
# 103        always set success greater los angeles area                0.0
# 102  business intelligence analytics travelers grea...                0.0
# 4     people development coordinator ryan denton texas                0.0
# 5    advisory board member celal bayar university i...                0.0
# 98                               student houston texas                0.0
# 96   student indiana university kokomo business man...                0.0
# 93   admissions representative community medical ce...                0.0
# 92   seek employment opportunities within customer ...                0.0
# 91   lead official western illinois university grea...                0.0
# 90   undergraduate research assistant styczynski la...                0.0
# 2    native english teacher epik english program ko...                0.0
# 87   bachelor science biology victoria university w...                0.0
# 86   information systems specialist programmer love...                0.0
# 85   recommend retail price brand portfolio executi...                0.0
# 11   student chapman university lake forest california                0.0
# 104  director administration excellence log katy texas                0.0

# %% [markdown]
# ### Word2Vec Model to make the re-ranking when a candidated is starred

# %%
candidate_id = 1
if candidate_id not in data.index:
    print('Candidate ID NOT valid!')

else:
    print('Candidate ID is valid!')
# Out:
# Candidate ID is valid!

# %%
feature = 'job_title'
keywords = word_tokenize(data[feature][candidate_id])

d_w2v_starred = data.copy()
d_w2v_starred  = word2vector(feature, keywords, d_w2v_starred)
d_w2v_starred
# Out:
#                                              job_title  \
# id
# 1    bauer college business graduate great distinct...
# 73   aspire human resources manager seek internship...
# 75   nortia staff seek human resources payroll admi...
# 76   aspire human resources professional passionate...
# 77   human resources conflict management policies p...
# 79   liberal arts major aspire human resources analyst
# 81   senior human resources business partner heil e...
# 82   aspire human resources professional energetic ...
# 83   human resources manager endemol shine north am...
# 84   human resources professional world leader gi s...
# 88                    human resources management major
# 89                         director human resources ey
# 94   seek human resources opportunities open travel...
# 96   student indiana university kokomo business man...
# 97                 aspire human resources professional
# 99                       seek human resources position
# 100  aspire human resources manager graduate may se...
# 101                 human resources generalist loparex
# 102          business intelligence analytics travelers
# 74                        human resources professional
# 78                   human resources generalist schwan
# 72   business management major aspire human resourc...
# 28                  seek human resources opportunities
# 8                    human resources senior specialist
# 7    student humber college aspire human resources ...
# 71          human resources generalist scottmadden inc
# 12   senior vice president chief human resources of...
# 6                    aspire human resources specialist
# 13   human resources coordinator intercontinental b...
# 10   seek human resources human resources informati...
# 27   aspire human resources management student seek...
# 66   experience retail manager aspire human resourc...
# 3                  aspire human resources professional
# 67          human resources staff recruit professional
# 68                human resources specialist luxottica
# 69   director human resources north america groupe ...
# 70   retire army national guard recruiter office ma...
# 4                  people development coordinator ryan
# 5         advisory board member celal bayar university
# 103                                 always set success
# 98                                             student
# 95                  student westfield state university
# 11                          student chapman university
# 93   admissions representative community medical ce...
# 92   seek employment opportunities within customer ...
# 91           lead official western illinois university
# 90     undergraduate research assistant styczynski lab
# 87   bachelor science biology victoria university w...
# 86   information systems specialist programmer love...
# 85   recommend retail price brand portfolio executi...
# 80             junior mes engineer information systems
# 2    native english teacher epik english program korea
# 104             director administration excellence log
#
#                                location connection  \
# id
# 1                         houston texas         85
# 73                        houston texas          7
# 75                  san jose california      500+
# 76                    new york new york        212
# 77               dallas fort worth area        409
# 79           baton rouge louisiana area          7
# 81           chattanooga tennessee area        455
# 82                         austin texas        174
# 83               los angeles california        268
# 84                  highland california         50
# 88                  milpitas california         18
# 89                 greater atlanta area        349
# 94                  unite state america        415
# 96                    lafayette indiana         19
# 97                       kokomo indiana         71
# 99                las vegas nevada area         48
# 100             cape girardeau missouri        103
# 101  raleigh durham north carolina area      500+
# 102          greater new york city area         49
# 74                  greater boston area         16
# 78                  unite state america      500+
# 72                monroe louisiana area          5
# 28                     chicago illinois        390
# 8                san francisco bay area      500+
# 7                                canada         61
# 71   raleigh durham north carolina area      500+
# 12                        houston texas      500+
# 6            greater new york city area          1
# 13                      atlanta georgia      500+
# 10            greater philadelphia area      500+
# 27                        houston texas      500+
# 66                         austin texas         57
# 3    raleigh durham north carolina area         44
# 67             jackson mississippi area      500+
# 68           greater new york city area      500+
# 69   greater grand rapids michigan area      500+
# 70              virginia beach virginia         82
# 4                          denton texas      500+
# 5                         i̇zmir turkey      500+
# 103            greater los angeles area      500+
# 98                        houston texas          4
# 95            bridgewater massachusetts         57
# 11               lake forest california          2
# 93                long beach california          9
# 92                  torrance california         64
# 91                 greater chicago area         39
# 90                 greater atlanta area        155
# 87                   baltimore maryland         40
# 86                gaithersburg maryland          4
# 85            greater philadelphia area      500+
# 80     myrtle beach south carolina area         52
# 2                                canada      500+
# 104                          katy texas      500+
#
#                                               keywords  cosine_similarity
# id
# 1    bauer college business graduate great distinct...                1.0
# 73   aspire human resources manager seek internship...                1.0
# 75   nortia staff seek human resources payroll admi...                1.0
# 76   aspire human resources professional passionate...                1.0
# 77   human resources conflict management policies p...                1.0
# 79   liberal arts major aspire human resources anal...                1.0
# 81   senior human resources business partner heil e...                1.0
# 82   aspire human resources professional energetic ...                1.0
# 83   human resources manager endemol shine north am...                1.0
# 84   human resources professional world leader gi s...                1.0
# 88   human resources management major milpitas cali...                1.0
# 89    director human resources ey greater atlanta area                1.0
# 94   seek human resources opportunities open travel...                1.0
# 96   student indiana university kokomo business man...                1.0
# 97   aspire human resources professional kokomo ind...                1.0
# 99   seek human resources position las vegas nevada...                1.0
# 100  aspire human resources manager graduate may se...                1.0
# 101  human resources generalist loparex raleigh dur...                1.0
# 102  business intelligence analytics travelers grea...                1.0
# 74    human resources professional greater boston area                1.0
# 78   human resources generalist schwan unite state ...                1.0
# 72   business management major aspire human resourc...                1.0
# 28   seek human resources opportunities chicago ill...                1.0
# 8    human resources senior specialist san francisc...                1.0
# 7    student humber college aspire human resources ...                1.0
# 71   human resources generalist scottmadden inc ral...                1.0
# 12   senior vice president chief human resources of...                1.0
# 6    aspire human resources specialist greater new ...                1.0
# 13   human resources coordinator intercontinental b...                1.0
# 10   seek human resources human resources informati...                1.0
# 27   aspire human resources management student seek...                1.0
# 66   experience retail manager aspire human resourc...                1.0
# 3    aspire human resources professional raleigh du...                1.0
# 67   human resources staff recruit professional jac...                1.0
# 68   human resources specialist luxottica greater n...                1.0
# 69   director human resources north america groupe ...                1.0
# 70   retire army national guard recruiter office ma...                1.0
# 4     people development coordinator ryan denton texas                0.0
# 5    advisory board member celal bayar university i...                0.0
# 103        always set success greater los angeles area                0.0
# 98                               student houston texas                0.0
# 95   student westfield state university bridgewater...                0.0
# 11   student chapman university lake forest california                0.0
# 93   admissions representative community medical ce...                0.0
# 92   seek employment opportunities within customer ...                0.0
# 91   lead official western illinois university grea...                0.0
# 90   undergraduate research assistant styczynski la...                0.0
# 87   bachelor science biology victoria university w...                0.0
# 86   information systems specialist programmer love...                0.0
# 85   recommend retail price brand portfolio executi...                0.0
# 80   junior mes engineer information systems myrtle...                0.0
# 2    native english teacher epik english program ko...                0.0
# 104  director administration excellence log katy texas                0.0
